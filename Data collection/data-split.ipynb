# %%
import pandas as pd

# %%
df = pd.read_csv('biotech_stock_data.csv')
df.head()
# Out:
#    Unnamed: 0 ticker  2015-12-22  2015-12-23  2015-12-24  2015-12-28  \
# 0           0    NVO     49.0179     49.5701     49.7771     50.2947
# 1           1   VRTX    121.0900    123.9200    124.3800    123.9900
# 2           2   REGN    535.5900    531.0600    535.5600    536.4500
# 3           4   SGEN     42.3100     42.7300     43.7100     43.7000
# 4           5   ALNY     88.2700     87.2400     91.2900     90.1600
#
#    2015-12-29  2015-12-30  2015-12-31  2016-01-04  ...  2019-12-17  \
# 0     50.4069     50.6312     50.2947     49.8548  ...     54.9628
# 1    124.9700    127.6800    125.5500    123.0300  ...    219.7200
# 2    542.2800    550.5400    542.6200    531.7600  ...    375.7300
# 3     44.5100     45.3000     44.8200     43.8800  ...    115.2000
# 4     92.4900     93.4800     94.1800     92.1800  ...    123.7000
#
#    2019-12-18  2019-12-19  2019-12-20  2019-12-23  2019-12-24  2019-12-26  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ticker', '2015-12-22', '2015-12-23', '2015-12-24',
#        '2015-12-28', '2015-12-29', '2015-12-30', '2015-12-31', '2016-01-04',
#        ...
#        '2019-12-17', '2019-12-18', '2019-12-19', '2019-12-20', '2019-12-23',
#        '2019-12-24', '2019-12-26', '2019-12-27', '2019-12-30', '2019-12-31'],
#       dtype='object', length=1015)

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.head()
# Out:
#   ticker  2015-12-22  2015-12-23  2015-12-24  2015-12-28  2015-12-29  \
# 0    NVO     49.0179     49.5701     49.7771     50.2947     50.4069
# 1   VRTX    121.0900    123.9200    124.3800    123.9900    124.9700
# 2   REGN    535.5900    531.0600    535.5600    536.4500    542.2800
# 3   SGEN     42.3100     42.7300     43.7100     43.7000     44.5100
# 4   ALNY     88.2700     87.2400     91.2900     90.1600     92.4900
#
#    2015-12-30  2015-12-31  2016-01-04  2016-01-05  ...  2019-12-17  \
# 0     50.6312     50.2947     49.8548       50.01  ...     54.9628
# 1    127.6800    125.5500    123.0300      123.89  ...    219.7200
# 2    550.5400    542.6200    531.7600      519.38  ...    375.7300
# 3     45.3000     44.8200     43.8800       42.07  ...    115.2000
# 4     93.4800     94.1800     92.1800       93.49  ...    123.7000
#
#    2019-12-18  2019-12-19  2019-12-20  2019-12-23  2019-12-24  2019-12-26  \
# ...

# %%
import random
from functools import reduce

# %%
indices = [i for i in range(48)]
random.shuffle(indices)

# %%
index_sets = [
    [0, 2, 7, 9, 10, 11, 12, 13, 17, 18, 20, 22, 23, 24, 25, 26, 29, 30, 33, 34, 35, 36, 37, 40, 47],
    [0, 1, 3, 4, 5, 8, 9, 14, 17, 18, 19, 21, 23, 25, 27, 31, 32, 33, 36, 38, 40, 41, 42, 44, 45],
    [3, 4, 6, 8, 10, 11, 13, 15, 16, 19, 21, 22, 27, 28, 30, 34, 33, 37, 39, 41, 43, 44, 45, 46, 47],
    [1, 2, 3, 5, 6, 7, 9, 12, 14, 15, 16, 20, 24, 26, 28, 29, 31, 32, 35, 38, 39, 42, 43, 46, 4]
]

# %%
for i, index_set in enumerate(index_sets):
    temp_df = df.loc[index_set].reset_index(drop=True)
    print(temp_df.head())
    temp_df.to_csv(f'testing_splits/set_{i}.csv')
# Out:
#   ticker  2015-12-22  2015-12-23  2015-12-24  2015-12-28  2015-12-29  \
# 0    NVO     49.0179     49.5701     49.7771     50.2947     50.4069
# 1   REGN    535.5900    531.0600    535.5600    536.4500    542.2800
# 2   TECH     83.8159     85.2154     85.3011     86.6815     87.7763
# 3   JAZZ    139.9900    144.1500    144.2400    141.7800    142.6500
# 4   SRPT     37.9200     37.4800     38.3500     38.3100     37.8100
#
#    2015-12-30  2015-12-31  2016-01-04  2016-01-05  ...  2019-12-17  \
# 0     50.6312     50.2947     49.8548     50.0100  ...     54.9628
# 1    550.5400    542.6200    531.7600    519.3800  ...    375.7300
# 2     87.4241     86.4816     84.7965     84.0635  ...    217.1782
# 3    142.5600    142.5500    137.8300    138.3500  ...    149.2200
# 4     39.5000     38.5500     37.8500     38.2000  ...    135.7900
#
#    2019-12-18  2019-12-19  2019-12-20  2019-12-23  2019-12-24  2019-12-26  \
# ...
